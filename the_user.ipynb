# %% [markdown]
# # 🔭 Quasar Research Notebook
#
# **Query:** The user has the following relevant documents in their personal knowledge base:
#
# [From: alma_pipeline_users_guide_2025.pdf]
# |Object|Species: Topocentric frequency ranges flagged (GHz)|
# |---|---|
# |**Mars**|CO:<br>[115.204,115.338], [230.404,230.672], [345.595,345.997], [460.773,461.309],<br>[691.071,691.875], [806.184,807.120], [921.265,922.335]<br>13CO:<br>[110.190,110.212], [220.377,220.421], [330.555,330.621], [440.721,440.809],<br>[661.001,661.133], [771.108,771.260], [881.196,881.370]|
# |**Venus**|CO:<br>[115.206,115.337], [230.407,230.669], [345.600,345.992], [460.779,461.303],<br>[691.081,691.865], [806.194,807.110], [921.277,922.323]<br>13CO:<br>[110.192,110.210], [220.380,220.418], [330.560,330.616], [440.727,440.803],<br>[661.011,661.123], [771.118,771.250], [881.208,881.358]|
#
# ---
# [From: archive-primer.pdf]
# #### **2.4 Example: star-forming regions on the spiral arms in M 83**
#
#
# Consider an example study into the spatial distribution of star-forming molecular clouds within the nearby faceon spiral galaxy M 83. Figure 2.5 shows an example of a search using “M83” as the source name and a frequency
# range of 230-232 GHz (using “230..232” in the Frequency box as explained in Section 2.3.1). This range covers
# the [12] CO(2–1) line at 230.530 GHz, which is a strong spectral line that can be used as a tracer of these molecular
#
#
# 5The ADMIT software package is available at `[https://admit.astro.umd.edu/index.html](https://admit.astro.umd.edu/index.html)` .
# 6The CARTA website is accessible at `[https://cartavis.github.io/](https://cartavis.github.io/)` .
#
#
# 12
#
# ---
# [From: alma_pipeline_users_guide_2025.pdf]
# |**Titan**|CO:<br>[114.92,115.67], [229.49,231.74], [343.82,347.62], [458.29,463.80],<br>[687.75,694.66], [803.46,809.85]<br>13CO:<br>[110.18,110.22], [220.28,220.52], [330.36,330.82], [440.42,441.15],<br>[660.60,661.53], [770.65,771.72], [880.73,881.82]<br>HCN:<br>[88.45,88.81], [176.73,177.80], [264.96,266.81], [353.29,355.72],<br>[441.74,444.52], [618.45,622.16], [707.01,710.74], [795.56,799.31],<br>[883.82,887.86]<br>HC15N:<br>[86.04,86.07], [172.05,172.16], [258.04,258.27], [430.02,430.45],<br>[601.95,602.60], [773.88,774.64], [859.84,860.62]|
# |_table continued on next page_|_table continued on next page_|
#
# ---
# [From: archive-primer.pdf]
# Figure 2.4: An example of the CARTA image viewer displaying the CS(5–4) image cube of the AGB star
# IRC+10216.
#
#
# clouds. Once M 83 is selected, the redshift will be indicated at the top of the top right panel and applied to the
# spectral line transitions shown in the spectral coverage plots.
#
#
# This initial search returns 36 observations belonging to 6 projects. The image pane will show the footprint
# of each observation. For investigating star formation in the spiral arms, the large mosaics covering the inner
# spiral arms of M 83 may be useful. Hovering over one of the outer footprints will show that they belong to
# project 2015.1.00121.S and, at the same time, highlight the spectral line coverage in bright yellow in the spectral
# coverage panel (see Figure 2.6).
#
# ---
# User's question: Check CO(2-1) line coverage for M87
#
# *Auto-generated by the Quasar Multi-Agent Workforce.*
#
# This notebook contains the code to reproduce each step of the analysis that was performed.

# %%
# Install required packages (uncomment if needed)
# !pip install astroquery pyvo astropy matplotlib spectral-cube numpy requests

# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.coordinates import SkyCoord
import astropy.units as u
import warnings
warnings.filterwarnings('ignore')

# Optional: ALMA archive access
try:
    from astroquery.alma import Alma
    from astroquery.simbad import Simbad
except ImportError:
    print('Install astroquery: pip install astroquery')

# Optional: visualization
try:
    from astropy.visualization import ZScaleInterval, ImageNormalize, SqrtStretch
except ImportError:
    pass

# %% [markdown]
# ## 📋 Instructions
#
# 1. Start by importing the required Astropy and Astroquery libraries.
# 2. Follow the steps sequentially to reproduce the research logic.
# 3. Replace generic tokens like `TARGET_NAME` or `QUERY` with your specific dataset parameters.

# %% [markdown]
# ### Step 1: Search the ALMA archive for target M87 using search_by_target.
#
# The following code demonstrates how to perform this analytical step programmatically.

# %%
# Step: Search the ALMA archive for target M87 using search_by_target.
from astroquery.alma import Alma
import pandas as pd

# Search ALMA archive for M87
rs = Alma.query_object('M87')
df = rs.to_pandas()
print(f'Found {len(df)} ALMA observations of M87')
df[['target_name', 'band_list', 's_resolution', 't_exptime']].head(10)

# %% [markdown]
# ### Step 2: Check whether the CO(2-1) line at approximately 230.538 GHz is covered in the last M87 search results using check_co_lines.
#
# The following code demonstrates how to perform this analytical step programmatically.

# %%
# Step: Check whether the CO(2-1) line at approximately 230.538 GHz is covered in the last M87 search results using check_co_lines.
from astroquery.alma import Alma
import pandas as pd

# Search ALMA archive for M87
rs = Alma.query_object('M87')
df = rs.to_pandas()
print(f'Found {len(df)} ALMA observations of M87')
df[['target_name', 'band_list', 's_resolution', 't_exptime']].head(10)

# %% [markdown]
# ### Step 3: Synthesize the ALMA search and CO line coverage results into a concise answer about CO(2-1) coverage for M87.
#
# The following code demonstrates how to perform this analytical step programmatically.

# %%
# Step: Synthesize the ALMA search and CO line coverage results into a concise answer about CO(2-1) coverage for M87.
from astroquery.alma import Alma
import pandas as pd

# Search ALMA archive for M87
rs = Alma.query_object('M87')
df = rs.to_pandas()
print(f'Found {len(df)} ALMA observations of M87')
df[['target_name', 'band_list', 's_resolution', 't_exptime']].head(10)

# %% [markdown]
# ---
#
# *Notebook auto-generated by [Quasar](https://github.com/your-org/quasar). Feel free to modify and extend.*
